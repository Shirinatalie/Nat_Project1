# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
# Configure the map plot
import hvplot.pandas
import holoviews as hv
from holoviews import opts
import seaborn as sns
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file into a Pandas DataFrame
Airbnb_data_df = pd.read_csv("C:\Class Folder\Project testing\.ipynb_checkpoints\listingss.csv")

# Drop unnecessary columns
data = Airbnb_data_df.drop(columns=["id","neighbourhood_group","license","last_review","host_id","host_name"])
# Remove rows with missing or unrealistic values
data = data.dropna(subset=["name", "neighbourhood"])
data = data[data["price"] > 0]


# Display sample data
data.head(50)
# Out:
#                                                  name           neighbourhood  \
# 0                    Lovely large room, Bethnal Green           Tower Hamlets
# 1                 Holiday London DB Room Let-on going               Islington
# 2                 COSY STUDIO-FLAT WITH A GREAT  VIEW           Tower Hamlets
# 3                A Luxury Studio Suite in Clerkenwell               Islington
# 4                 Notting Hill church stay in Heaven!  Kensington and Chelsea
# 5                 Bright Chelsea  Apartment. Chelsea!  Kensington and Chelsea
# 6              JESSIE the narrowboat in Little Venice             Westminster
# 7               Superb 3-Bed/2 Bath & Wifi: Trendy W1             Westminster
# 8                      APARTMENT IN NORTH WEST LONDON                  Harrow
# 9                     DOUBLE ROOM NEAR CENTRAL LONDON                 Enfield
# 10   A stylish original Victorian home in West London  Hammersmith and Fulham
# 11      Gorgeous Modern 3 Bed Flat in Willesden Green                   Brent
# 12  Battersea live/work artist house, garden communal              Wandsworth
# 13  Double bedroom in cottage Twickenham (sleeps 1-2)    Richmond upon Thames
# 14                  Double Bedroom in Victorian House                  Newham
# 15               1 bedroom apartment close to centre.                 Lambeth
# 16                     Single room in Victorian house                  Newham
# 17                  Clean big Room in London (Room 1)                  Barnet
# 18                I Bedroom Apartment Tower of London          City of London
# 19          Restful Room, Friendly House, East London                  Newham
# 20     Beautiful Ensuite Richmond-upon-Thames borough    Richmond upon Thames
# 21                   Executive House for Olypmic 2012                  Newham
# 22  Elegant Very Central: Fitzrovia W1. King Bed, ...                  Camden
# 23      Architect designed Camden canalside townhouse                  Camden
# 24                Kew Gardens 3BR house in cul-de-sac    Richmond upon Thames
# 25                Stylish & Bright, 1 Bed, Shoreditch                 Hackney
# 26                    You are GUARANTEED to love this                Haringey
# 27                 FREE WIFI Double room in SW London                 Lambeth
# 28   Entire London Town House Next 2 Tube & Wimbledon                  Merton
# 29          Compact living cosy studio flat in London                  Barnet
# 30              Home from Home in the heart of London  Hammersmith and Fulham
# 31         SUNNY ROOM PRIVATE BATHROOM PLUS BREAKFAST  Hammersmith and Fulham
# 32                               CHARMING FAMILY HOME  Hammersmith and Fulham
# 33                 Large room, London Fields, Hackney                 Hackney
# 34   Room 1 Large Double Bedroom - front ground floor                Haringey
# 35         West London-W7, Hanwell (Area Ealing) Room                  Ealing
# 36           Stylish bedsit in Notting Hill ish flat.             Westminster
# 37                   A people person awaits you here!          Waltham Forest
# 38       Spacious 2-bed Muswell Hill garden apartment                Haringey
# 39                   bedroom to rent in SW17 - London                  Merton
# 40          Room 4 Cosy Double Bedroom on First Floor                Haringey
# 41                  great location absolutely central             Westminster
# 42                  Clean big Room in London (Room 2)                  Barnet
# 43                   Entire Apartment short/long stay                 Lambeth
# 44  Quiet double room, with friendly, experienced ...               Southwark
# 45                 Cheap London Wembley apartment !!!                   Brent
# 46  2 Double bed apartment in quiet area North London                  Barnet
# 47                     Room in maisonette in chiswick                Hounslow
# 48                West London,loft ensuite, 5min2tube  Hammersmith and Fulham
# 49         Room with a view  zone 1  Central Bankside               Southwark
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 0   51.52874   -0.05396     Private room     55               3
# 1   51.56861   -0.11270     Private room     50               1
# 2   51.52851   -0.07426  Entire home/apt     90               5
# 3   51.52478   -0.10484     Private room    180               4
# 4   51.51464   -0.20004  Entire home/apt    297              14
# 5   51.48780   -0.16813  Entire home/apt     75               3
# 6   51.52055   -0.18317  Entire home/apt    204               2
# 7   51.52195   -0.14094  Entire home/apt    379               4
# 8   51.57982   -0.37539  Entire home/apt     90               3
# 9   51.61137   -0.11888     Private room     30               7
# 10  51.50155   -0.23300  Entire home/apt    136               5
# 11  51.53741   -0.23727  Entire home/apt    102               2
# 12  51.47072   -0.16266  Entire home/apt    195               3
# 13  51.44777   -0.33962     Private room   1000               2
# 14  51.52185    0.02417     Private room     45               7
# 15  51.49148   -0.11151  Entire home/apt    100               3
# 16  51.52185    0.02417     Private room     45               7
# 17  51.57438   -0.21081     Private room     29              10
# 18  51.51099   -0.07862  Entire home/apt    130               5
# 19  51.53403    0.02709     Private room     34               1
# 20  51.46410   -0.32498     Private room     95               2
# 21  51.53667    0.00562  Entire home/apt    572              14
# 22  51.52197   -0.14035  Entire home/apt    185               3
# 23  51.54039   -0.14282  Entire home/apt    275               2
# 24  51.48085   -0.28086  Entire home/apt    245               3
# 25  51.52851   -0.08985  Entire home/apt    180               3
# 26  51.58478   -0.16057     Private room     72               2
# 27  51.42900   -0.12764     Private room     29               2
# 28  51.40066   -0.19158  Entire home/apt    279               2
# 29  51.59375   -0.25767  Entire home/apt     65               7
# 30  51.48641   -0.21277     Private room    120               2
# 31  51.50681   -0.23345     Private room     62               2
# 32  51.50701   -0.23362  Entire home/apt    200              14
# 33  51.54017   -0.05457     Private room     35               1
# 34  51.58684   -0.08632     Private room     45               1
# 35  51.50426   -0.33444     Private room     33               7
# 36  51.52605   -0.19942     Private room     42               5
# 37  51.57537    0.00536     Private room     40               2
# 38  51.58409   -0.14625  Entire home/apt    170               4
# 39  51.41877   -0.16772     Private room     45               1
# 40  51.58738   -0.08792     Private room     45               1
# 41  51.48970   -0.13911  Entire home/apt     83               2
# 42  51.57400   -0.21058     Private room     25              10
# 43  51.42892   -0.12915  Entire home/apt    135               7
# 44  51.48849   -0.08616     Private room     52               5
# 45  51.55764   -0.30173  Entire home/apt     59               1
# 46  51.61492   -0.25632  Entire home/apt    550               4
# 47  51.49351   -0.25568     Private room    150               1
# 48  51.48974   -0.22208     Private room     90               4
# 49  51.50191   -0.10204     Private room     95               2
#
#     number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  65               0.47                               1
# 1                  30               0.20                               2
# 2                  42               0.34                               1
# 3                 493               3.59                               5
# 4                   6               0.05                               1
# 5                  89               0.57                               1
# 6                 581               4.26                               1
# 7                  51               0.36                               5
# 8                 104               0.86                               1
# 9                  32               0.29                               1
# 10                 71               0.55                               1
# 11                  0                NaN                               1
# 12                 96               0.67                               1
# 13                  0                NaN                               1
# 14                 46               0.35                               6
# 15                129               0.96                               2
# 16                 38               0.30                               6
# 17                129               0.85                               3
# 18                213               1.57                               2
# 19                122               0.82                               2
# 20                 20               0.14                               2
# 21                  0                NaN                               1
# 22                 63               0.53                               5
# 23                 17               0.16                               1
# 24                 96               0.66                               1
# 25                 96               0.71                               1
# 26                575               3.94                               2
# 27                  1               0.01                               2
# 28                  5               0.08                               3
# 29                119               0.93                               3
# 30                226               1.77                               1
# 31                379               2.62                               2
# 32                 37               0.30                               2
# 33                 24               0.26                               7
# 34                  1               0.11                               3
# 35                103               0.76                               2
# 36                 10               0.10                               1
# 37                 55               0.45                               1
# 38                  6               0.04                               1
# 39                  0                NaN                               1
# 40                  0                NaN                               3
# 41                  1               0.01                               1
# 42                 84               0.58                               3
# 43                  0                NaN                               2
# 44                192               1.53                               2
# 45                173               1.37                               1
# 46                 21               0.17                               1
# 47                 71               0.52                               1
# 48                167               1.23                               1
# 49                106               0.75                               1
#
#     availability_365  number_of_reviews_ltm
# 0                 74                      0
# 1                343                      9
# 2                222                      1
# 3                236                     20
# 4                180                      2
# 5                 70                      0
# 6                193                     66
# 7                249                      8
# 8                318                      4
# 9                251                      4
# 10                 0                     10
# 11                 0                      0
# 12               116                      3
# 13                 0                      0
# 14                40                      4
# 15                 1                      5
# 16               105                      2
# 17                 0                      0
# 18                 1                      0
# 19                 0                      6
# 20               363                     13
# 21               365                      0
# 22               197                      6
# 23                 0                      0
# 24               224                     14
# 25                11                     12
# 26                 2                     37
# 27               330                      0
# 28                90                      1
# 29               318                      9
# 30               362                      8
# 31                 4                     13
# 32               259                      1
# 33                 0                      1
# 34                68                      1
# 35                10                      5
# 36                 0                      0
# 37               302                     10
# 38                 0                      0
# 39                 0                      0
# 40               358                      0
# 41                 0                      0
# 42                 0                      0
# 43               356                      0
# 44                 0                      0
# 45               152                      0
# 46               358                      0
# 47               128                      0
# 48                62                      6
# 49               345                     22

# %%
# Calculate the total number of unique Airbnbs
Airbnb_count =len(data["name"].unique())
Airbnb_count
# Out:
# 67016

# %%
# Unique Airbnbs
Airbnb_unique = data["name"].unique()
Airbnb_unique
# Out:
# array(['Lovely large room, Bethnal Green',
#        'Holiday London DB Room Let-on going',
#        'COSY STUDIO-FLAT WITH A GREAT  VIEW', ...,
#        'Luxury 4 bed house, 100m to river and palace',
#        'Waterfront Hampton Stay',
#        'GuestReady Gorgeous Bright 2 Br Apartment in'], dtype=object)

# %%
# Calculate central tendencies
average_price = data["price"].mean()
median_price = data["price"].median()
mode_price = data["price"].mode()
min_price = data["price"].min()
max_price = data["price"].max()
price_range = max_price - min_price

# Create a DataFrame
central_tendencies_df = pd.DataFrame({
    "Statistic": ["Mean", "Median", "Mode", "Minimum", "Maximum", "Range"],
    "Price": [average_price, median_price, mode_price.values[0], min_price, max_price, price_range]
})

# Display the DataFrame
central_tendencies_df.head(6)
# Out:
#   Statistic        Price
# 0      Mean    177.29043
# 1    Median    100.00000
# 2      Mode    100.00000
# 3   Minimum      1.00000
# 4   Maximum  25000.00000
# 5     Range  24999.00000

# %%
# Sort the airbnbs by number of reviews in descending order and display the top 5 rows.
sorted_airbnbs_top5 = data.sort_values(by='number_of_reviews', ascending=False)

# Display the top 5 rows
sorted_airbnbs_top5.head(5)
# Out:
#                                                     name  neighbourhood  \
# 19324        Designer Studio Apartment in Central London  Tower Hamlets
# 31651    Double Garden View room - London House Hotel***    Westminster
# 1507                 Cosy Dble in Kings Cross Houseshare         Camden
# 1969   London's best transport hub 5 mins walk! Safe ...      Islington
# 46488                               Double Room+ Ensuite         Camden
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 19324  51.51421   -0.07062  Entire home/apt    361               1
# 31651  51.51397   -0.18949     Private room    343               1
# 1507   51.53087   -0.12672     Private room     85               1
# 1969   51.53442   -0.11988     Private room     59               1
# 46488  51.52998   -0.12193     Private room    167               1
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 19324               1141              21.79                               7
# 31651               1066              24.17                              23
# 1507                 929               8.49                               4
# 1969                 784               7.65                               1
# 46488                758              51.33                               7
#
#        availability_365  number_of_reviews_ltm
# 19324               357                    248
# 31651               319                    631
# 1507                246                     74
# 1969                242                    121
# 46488               336                    660

# %%
# Sort the airbnbs by number of reviews in ascending order and display the top 5 rows.
sorted_airbnbs_bottom5 = data.sort_values(by='number_of_reviews', ascending=True)

# Display the top 5 rows
sorted_airbnbs_bottom5.head(5)
# Out:
#                                                     name  \
# 42490                         Single Room in Hammersmith
# 64266                                Steps of the market
# 22638               Ground Floor Flat in quiet Islington
# 12281                        Lovely Double, Nr Wimbledon
# 12282  Bright and airy studio apartment near Camden Town
#
#                 neighbourhood   latitude  longitude        room_type  price  \
# 42490  Hammersmith and Fulham  51.489140  -0.229010     Private room     40
# 64266               Southwark  51.501494  -0.033853  Entire home/apt    195
# 22638               Islington  51.563610  -0.125030     Private room     40
# 12281              Wandsworth  51.446400  -0.186640     Private room     45
# 12282                  Camden  51.533550  -0.137620  Entire home/apt     80
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 42490               5                  0                NaN
# 64266              16                  0                NaN
# 22638               2                  0                NaN
# 12281               1                  0                NaN
# 12282               3                  0                NaN
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 42490                               1                 0                      0
# 64266                               1               365                      0
# 22638                               1                 0                      0
# 12281                               1                 0                      0
# 12282                               1                 0                      0

# %%
# Establish the bins 
# Define the price bins and labels with fewer bins
price_bins = [0, 100, 200, 300, 400, 500, 1000, 5000, 10000, 25000]
price_labels = ['0-100', '101-200', '201-300', '301-400', '401-500', '501-1000', '1001-5000', '5001-10000', '10001-25000']

# Create a new column 'price_range' based on the bins
data['price_range'] = pd.cut(data['price'], bins=price_bins, labels=price_labels)

# Check the result
print(data[['price', 'price_range']].head(50))
# Out:
#     price price_range
# 0      55       0-100
# 1      50       0-100
# 2      90       0-100
# 3     180     101-200
# 4     297     201-300
# 5      75       0-100
# 6     204     201-300
# 7     379     301-400
# 8      90       0-100
# 9      30       0-100
# 10    136     101-200
# 11    102     101-200
# 12    195     101-200
# 13   1000    501-1000
# 14     45       0-100
# 15    100       0-100
# 16     45       0-100
# 17     29       0-100
# 18    130     101-200
# 19     34       0-100
# 20     95       0-100
# 21    572    501-1000
# 22    185     101-200
# 23    275     201-300
# 24    245     201-300
# 25    180     101-200
# 26     72       0-100
# 27     29       0-100
# 28    279     201-300
# 29     65       0-100
# 30    120     101-200
# 31     62       0-100
# 32    200     101-200
# 33     35       0-100
# 34     45       0-100
# 35     33       0-100
# 36     42       0-100
# 37     40       0-100
# 38    170     101-200
# 39     45       0-100
# 40     45       0-100
# 41     83       0-100
# 42     25       0-100
# 43    135     101-200
# 44     52       0-100
# 45     59       0-100
# 46    550    501-1000
# 47    150     101-200
# 48     90       0-100
# 49     95       0-100

# %%
data['price_range'] = pd.cut(data['price'], bins=price_bins, labels=price_labels)

# %%
# Create a new DataFrame with the binned data
binned_data = data[['price', 'price_range']].copy()

# Combine it with the original DataFrame
combined_data = pd.concat([data, binned_data], axis=1)

# Display the combined DataFrame
combined_data.head()
# Out:
#                                    name           neighbourhood  latitude  \
# 0      Lovely large room, Bethnal Green           Tower Hamlets  51.52874
# 1   Holiday London DB Room Let-on going               Islington  51.56861
# 2   COSY STUDIO-FLAT WITH A GREAT  VIEW           Tower Hamlets  51.52851
# 3  A Luxury Studio Suite in Clerkenwell               Islington  51.52478
# 4   Notting Hill church stay in Heaven!  Kensington and Chelsea  51.51464
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0   -0.05396     Private room     55               3                 65
# 1   -0.11270     Private room     50               1                 30
# 2   -0.07426  Entire home/apt     90               5                 42
# 3   -0.10484     Private room    180               4                493
# 4   -0.20004  Entire home/apt    297              14                  6
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.47                               1                74
# 1               0.20                               2               343
# 2               0.34                               1               222
# 3               3.59                               5               236
# 4               0.05                               1               180
#
#    number_of_reviews_ltm price_range  price price_range
# 0                      0       0-100     55       0-100
# 1                      9       0-100     50       0-100
# 2                      1       0-100     90       0-100
# 3                     20     101-200    180     101-200
# 4                      2     201-300    297     201-300

# %% [markdown]
# ### Comparing prices of ranges of prices.

# %%
# Count the occurrences of each price range
price_range_counts = data['price_range'].value_counts()

# Create a pie chart with maximized space
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(price_range_counts, labels=price_range_counts.index, autopct='%1.1f%%', startangle=140)
ax.set_title('Distribution of Price Ranges')
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the pie chart
plt.show()

# %% [markdown]
# ## Boxplot with outliers

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(data['price'], vert=False, showfliers=True)  # showfliers=True to display outliers
plt.title('Box Plot of Prices')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# ## Boxplot without outliers

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(data['price'], vert=False, showfliers=False)  # showfliers=False to hide outliers
plt.title('Box Plot of Prices (Outliers Removed)')
plt.xlabel('Price')
plt.show()
